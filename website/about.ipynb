# %% [raw]
# ---
# title: "About me"
# html:
#     toc: false
# execute:
#   echo: true
# ---

# %% [markdown]
# James Hickman is an Assistant Teaching Professor in the Data Science and Analytics program at Georgetown University. He received his Ph.D. in Computational-Physics from George Mason University (GMU) in 2017, an M.S. in Engineering-Physics from GMU in 2014, and a double-major in Physics and Applied Mathematics from Shippensburg University in 2011. His graduate work focused on applying classical atomistic simulations to various material science and condensed matter physics problems. In 2018, he was awarded an NRC postdoctoral fellowship at the National Institute of Standards and Technology (NIST) in Gaithersburg, Maryland. [click me](https://quarto.org/docs/authoring/cross-references.html#figures) [^my_note]
#
# [^my_note]: https://quarto.org/docs/authoring/cross-references.html#figures
#
#
#
# <center> ![Photo of me](images/2023-09-06-23-12-12.png){#fig-elephant} </center>
#
# James Hickman is an Assistant Teaching Professor in the Data Science and Analytics program at Georgetown University. He received his Ph.D. in Computational-Physics from George Mason University (GMU) in 2017, an M.S. in Engineering-Physics from GMU in 2014, and a double-major in Physics and Applied Mathematics from Shippensburg University in 2011. His graduate work focused on applying classical atomistic simulations to various material science and condensed matter physics problems. In 2018, he was awarded an NRC postdoctoral fellowship at the National Institute of Standards and Technology (NIST) in Gaithersburg, Maryland.

# %% [markdown]
# # Education
#
# * This is an example of a bulleted list with math
# * Here is an in-line math equation $f(x)=\frac{e^{x^2}}{2}$
#
# $$g(x)=x^n \rightarrow \frac{\partial g}{\partial x}=n x^{n-1}$$
#
# ::: {layout-ncol=2}
# ### List One
#
# - Item A
# - Item B
# - Item C
#
# ### List Two
#
# - Item X
# - Item Y
# - Item Z
# :::

# %% [markdown]
# :::: {.columns}
# ::: {.column width="50%"}
# James Hickman is an Assistant Teaching Professor in the Data Science and Analytics program at Georgetown University. He received his Ph.D. in Computational-Physics from George Mason University (GMU) in 2017, an M.S. in Engineering-Physics from GMU in 2014, and a double-major in Physics and Applied Mathematics from Shippensburg University in 2011. His graduate work focused on applying classical atomistic simulations to various material science and condensed matter physics problems. In 2018, he was awarded an NRC postdoctoral fellowship at the National Institute of Standards and Technology (NIST) in Gaithersburg, Maryland.
#
# :::
#
# ::: {.column width="50%"}
# James Hickman is an Assistant Teaching Professor in the Data Science and Analytics program at Georgetown University. He received his Ph.D. in Computational-Physics from George Mason University (GMU) in 2017, an M.S. in Engineering-Physics from GMU in 2014, and a double-major in Physics and Applied Mathematics from Shippensburg University in 2011. His graduate work focused on applying classical atomistic simulations to various material science and condensed matter physics problems. In 2018, he was awarded an NRC postdoctoral fellowship at the National Institute of Standards and Technology (NIST) in Gaithersburg, Maryland.
#
# Black-Scholes (@eq-black-scholes) is a mathematical model that seeks to explain the behavior of financial derivatives, most commonly options:
#
# Black-Scholes (@eq-black-scholes-2) is a mathematical model that seeks to explain the behavior of financial derivatives, most commonly options:
#
# :::
# ::::
#
# ## Undergrad
#
# ## Grad-school

# %% [markdown]
# $$
# \frac{\partial \mathrm C}{ \partial \mathrm t } + \frac{1}{2}\sigma^{2} \mathrm S^{2}
# \frac{\partial^{2} \mathrm C}{\partial \mathrm C^2}
#   + \mathrm r \mathrm S \frac{\partial \mathrm C}{\partial \mathrm S}\ =
#   \mathrm r \mathrm C
# $$ {#eq-black-scholes}

# %% [markdown]
# ::: {.panel-tabset}
# ### rmarkdown
#
# hello
#
# ### quarto
#
# goodbye
# :::
#
# ```{mermaid}
# %%| fig-cap: "A Mermaid diagram"
# %%| code-fold: true
# flowchart LR
#   A[Hard edge] --> B(Round edge)
#   B --> C{Decision}
#   C --> D[Result one]
#   C --> E[Result two]
# ```

# %% [markdown]
# About this site!!!
#
# $$
# \frac{\partial \mathrm C}{ \partial \mathrm t } + \frac{1}{2}\sigma^{2} \mathrm S^{2}
# \frac{\partial^{2} \mathrm C}{\partial \mathrm C^2}
#   + \mathrm r \mathrm S \frac{\partial \mathrm C}{\partial \mathrm S}\ =
#   \mathrm r \mathrm C
# $$ {#eq-black-scholes-2}
#
#
# <!-- ![Elephant](images/2023-09-06-23-12-12.png){#fig-elephant} -->
#
#
# See @fig-elephant for examples.

# %% [markdown]
# ## EDA
#
# Create a simple plot.
#
# $$
# i \hbar \frac{d}{d t} \psi(t)=H \psi(t)
# $$
#
# "Here $H$ denotes the Hamiltonian, the observable corresponding to the total energy of the system, and $\hbar$ is the reduced Planck constant. The constant $i \hbar$ is introduced so that the Hamiltonian is reduced to the classical Hamiltonian in cases where the quantum system can be approximated by a classical system; the ability to make such an approximation in certain limits is called the correspondence principle. The solution of this differential equation is given by" [^wiki_QM]
#
# [^wiki_QM]: https://en.wikipedia.org/wiki/Quantum_mechanics
#
# $$
# \psi(t)=e^{-i H t / \hbar} \psi(0) .
# $$

# %%
#| echo: false

import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %%
#| label: fig-airquality
#| fig-cap: "Temperature and ozone level."
#| warning: false

library(ggplot2)

ggplot(airquality, aes(Temp, Ozone)) + 
  geom_point() + 
  geom_smooth(method = "loess")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# "Removed 37 rows containing non-finite values (`stat_smooth()`)."
# Warning message:
# "Removed 37 rows containing missing values (`geom_point()`)."
# plot without title

# %%
#| echo: false

import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()
